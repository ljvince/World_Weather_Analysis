# %%
import requests
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from citipy import citipy 
from config import weather_api_key

# %%
#set the 2000 coordinates 
lats = np.random.uniform(-90.000, 90.000, size=2000)
lngs = np.random.uniform(-90.000, 90.000, size=2000)
coordinates =list(zip(lats, lngs))
len(coordinates)
# Out:
# 2000

# %%
# Create a list for holding the cities.
cities = [ ]
for coordinate  in coordinates:
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
cities
# Out:
# ['marsabit',
#  'matsanga',
#  'cape town',
#  'barentsburg',
#  'namibe',
#  'bambous virieux',
#  'talnakh',
#  'saint-augustin',
#  'bredasdorp',
#  'lesnoy',
#  'longyearbyen',
#  'sambava',
#  'mahebourg',
#  'inta',
#  'jamestown',
#  'walvis bay',
#  'hermanus',
#  'caravelas',
#  'bandarbeyla',
#  'umzimvubu',
#  'east london',
#  'mecca',
#  'souillac',
#  'moose factory',
#  'port alfred',
#  'umm kaddadah',
#  'klaksvik',
#  'cobija',
#  'savinka',
#  'kolyvan',
#  'dikson',
#  'lodwar',
#  'burgersdorp',
#  'lasa',
#  'taolanaro',
#  'lagoa',
#  'grand gaube',
#  'bharatpur',
#  'taoudenni',
#  'ushuaia',
#  'lebu',
#  'sao filipe',
#  'olafsvik',
#  'qaanaaq',
#  'matara',
#  'warqla',
#  'punta arenas',
#  'leh',
#  'vyartsilya',
#  'sorland',
#  'vicuna',
#  'coruripe',
#  'senno',
#  'dokshukino',
#  'kudahuvadhoo',
#  'yar-sale',
#  'upernavik',
#  'mamlyutka',
#  'rio cuarto',
#  'paramonga',
#  'doaba',
#  'busselton',
#  'touros',
#  'yarada',
#  'ambodifototra',
#  'tsihombe',
#  'ribeira grande',
#  'santarem',
#  'muli',
#  'volchikha',
#  'cidreira',
#  'chinhoyi',
#  'aswan',
#  'kavaratti',
#  'margate',
#  'codrington',
#  'amparafaravola',
#  'tiznit',
#  'ipojuca',
#  'tilsonburg',
#  'marsa matruh',
#  'hofn',
#  'saint-pierre',
#  'bibbiena',
#  'cuenca',
#  'tasiilaq',
#  'strezhevoy',
#  'hun',
#  'kruisfontein',
#  'belushya guba',
#  'georgetown',
#  'pauini',
#  'cerro grande',
#  'aksarka',
#  'muzaffarabad',
#  'saint-denis',
#  'ponta do sol',
#  'arraial do cabo',
#  'salalah',
#  'revda',
#  'dingle',
#  'richards bay',
#  'wajid',
#  'iqaluit',
#  'copiapo',
#  'illoqqortoormiut',
#  'macaiba',
#  'nara',
#  'saint-philippe',
#  'huarmey',
#  'camopi',
#  'ourossogui',
#  'oktyabrskoye',
#  'barranca',
#  'vila velha',
#  'hithadhoo',
#  'ayagoz',
#  'grenaa',
#  'ndioum',
#  'soyo',
#  'torbay',
#  'dakar',
#  'skalistyy',
#  'victoria',
#  'bayshore gardens',
#  'kargasok',
#  'kulhudhuffushi',
#  'clyde river',
#  'bugarama',
#  'mehamn',
#  'grand river south east',
#  'sakakah',
#  'stod',
#  'port-cartier',
#  'encantado',
#  'quepos',
#  'lethem',
#  'kattivakkam',
#  'barcelos',
#  'narsaq',
#  'abu samrah',
#  'comodoro rivadavia',
#  'mar del plata',
#  'hualmay',
#  'iranshahr',
#  'babanusah',
#  'arinos',
#  'januaria',
#  'constitucion',
#  'mayumba',
#  'brasilia de minas',
#  'rurrenabaque',
#  'sidi ali',
#  'coquimbo',
#  'manturovo',
#  'naron',
#  'husavik',
#  'port hawkesbury',
#  'luderitz',
#  'barawe',
#  'rocha',
#  'girua',
#  'acarigua',
#  'ampanihy',
#  'santa cruz',
#  'coari',
#  'corn island',
#  'najran',
#  'saint george',
#  'bocas del toro',
#  'belyy yar',
#  'polunochnoye',
#  'malkara',
#  'rawson',
#  'jalu',
#  'ostersund',
#  'el cobre',
#  'beruwala',
#  'nanortalik',
#  'barabinsk',
#  'nove hrady',
#  'cheveresu mare',
#  'winneba',
#  'rome',
#  'roald',
#  'attawapiskat',
#  'ostrovnoy',
#  'ancud',
#  'asasa',
#  'biltine',
#  'amderma',
#  'marsh harbour',
#  'jacareacanga',
#  'hamilton',
#  'ladwa',
#  'faya',
#  'caucaia',
#  'camacha',
#  'zhovti vody',
#  'paamiut',
#  'hambantota',
#  'port blair',
#  'toamasina',
#  'bathsheba',
#  'kampene',
#  'kulachi',
#  'puerto baquerizo moreno',
#  'omboue',
#  'new glasgow',
#  'butembo',
#  'sistranda',
#  'kuche',
#  'muscat',
#  'harper',
#  'eatonton',
#  'tamandare',
#  'saldanha',
#  'oranjemund',
#  'utica',
#  'mocambique',
#  'castro',
#  'chuy',
#  'galle',
#  'darnah',
#  'terenos',
#  'ambilobe',
#  'skjervoy',
#  'krasnoselkup',
#  'ongandjera',
#  'kazalinsk',
#  'cabedelo',
#  'vardo',
#  'den helder',
#  'mercedes',
#  'stornoway',
#  'bujumbura',
#  'sobradinho',
#  'bardiyah',
#  'badarganj',
#  'altay',
#  'lohja',
#  'bauchi',
#  'guane',
#  'ilulissat',
#  'sinnamary',
#  'thunder bay',
#  'kuryk',
#  'olinda',
#  'mutare',
#  'pisco',
#  'coxim',
#  'bonavista',
#  'halifax',
#  'kalmunai',
#  'abaza',
#  'fomboni',
#  'rio gallegos',
#  'ponta pora',
#  'nador',
#  'port elizabeth',
#  'thinadhoo',
#  'santa isabel do rio negro',
#  'evinayong',
#  'sliema',
#  'areosa',
#  'maceio',
#  'acarau',
#  'iberia',
#  'almazar',
#  'tarauaca',
#  'makokou',
#  'longlac',
#  'shieli',
#  'altamira',
#  'bilma',
#  'porto novo',
#  'esil',
#  'buta',
#  'formoso do araguaia',
#  'beisfjord',
#  'shenkursk',
#  'brae',
#  'svilajnac',
#  'lokosovo',
#  'ponta delgada',
#  'young',
#  'sajanan',
#  'raudeberg',
#  'emba',
#  'tartagal',
#  'doha',
#  'barbar',
#  'appleton',
#  'mrirt',
#  'bosaso',
#  'lajoskomarom',
#  'sao felix do xingu',
#  'lincoln',
#  'khromtau',
#  'oriximina',
#  'oksbol',
#  'uch',
#  'wa',
#  'kismayo',
#  'kaduqli',
#  'paita',
#  'kodino',
#  'patrocinio',
#  'sao joao da barra',
#  'tambul',
#  'takob',
#  'zanjan',
#  'ratnagiri',
#  'naryan-mar',
#  'kouango',
#  'tumannyy',
#  'praia da vitoria',
#  'damghan',
#  'belmont',
#  'caiaponia',
#  'vista hermosa',
#  'carutapera',
#  'lumeje',
#  'crateus',
#  'esik',
#  'do gonbadan',
#  'pitimbu',
#  'solovetskiy',
#  'lyubeshiv',
#  'akdepe',
#  'voyvozh',
#  'mount pleasant',
#  'havelock',
#  'warrington',
#  'mookane',
#  'quthing',
#  'menongue',
#  'havoysund',
#  'palma del rio',
#  'laguna',
#  'bonthe',
#  'montepuez',
#  'tacuarembo',
#  'cayenne',
#  'umm jarr',
#  'emirdag',
#  'ribas do rio pardo',
#  'tuggurt',
#  'jaciara',
#  'rey bouba',
#  'tocopilla',
#  'mamou',
#  'montana',
#  'rodrigues alves',
#  'dzhusaly',
#  'juazeiro',
#  'takoradi',
#  'keetmanshoop',
#  'madras',
#  'antri',
#  'qasigiannguit',
#  'araouane',
#  'san luis',
#  'behbahan',
#  'larsnes',
#  'carnarvon',
#  'ilinskaya',
#  'luanda',
#  'dudinka',
#  'tena',
#  'bubaque',
#  'palma di montechiaro',
#  'wolow',
#  'north myrtle beach',
#  'camabatela',
#  'miranda',
#  'cockburn town',
#  'filadelfia',
#  'ust-kulom',
#  'staryy biser',
#  'korla',
#  'nicoya',
#  'antofagasta',
#  'diffa',
#  'kastamonu',
#  'bargal',
#  'saint-joseph',
#  'gasa',
#  'agirish',
#  'marawi',
#  'pangnirtung',
#  'arlit',
#  'sao borja',
#  'joensuu',
#  'chapais',
#  'george town',
#  'pampierstad',
#  'thompson',
#  'visby',
#  'falun',
#  'ilhabela',
#  'votorantim',
#  'alberton',
#  'turukhansk',
#  'hobyo',
#  'bukama',
#  'ituango',
#  'oxapampa',
#  'male',
#  'ouesso',
#  'itarema',
#  'leshukonskoye',
#  'gazojak',
#  'pitkyaranta',
#  'san juan bautista',
#  'bolungarvik',
#  'itacoatiara',
#  'sur',
#  'surab',
#  'viseu',
#  'muskegon',
#  'coihaique',
#  'zharkent',
#  'havre-saint-pierre',
#  'oktyabrskiy',
#  'oksfjord',
#  'mali',
#  'monze',
#  'salinopolis',
#  'rostov-na-donu',
#  'silvan',
#  'adrar',
#  'henties bay',
#  'porechye-rybnoye',
#  'san jose de guanipa',
#  'manati',
#  'lai',
#  'gat',
#  'semey',
#  'manassas',
#  'berlevag',
#  'otavi',
#  'mustafakemalpasa',
#  'borba',
#  'inongo',
#  'koslan',
#  'shahrud',
#  'grindavik',
#  'jutai',
#  'qaqortoq',
#  'bell ville',
#  'gijon',
#  'mocajuba',
#  'synya',
#  'san ignacio',
#  'anyksciai',
#  'saurimo',
#  'san cristobal',
#  'kargil',
#  'impfondo',
#  'salekhard',
#  'krasnoyarka',
#  'traverse city',
#  'imbituba',
#  'keti bandar',
#  'kupino',
#  'san vicente',
#  'poli',
#  'wanlaweyn',
#  'rundu',
#  'avanigadda',
#  'carbonia',
#  'san juan',
#  'andenes',
#  'basoko',
#  'bandar-e lengeh',
#  'dubna',
#  'gubkinskiy',
#  'adeje',
#  'cangucu',
#  'ituni',
#  'inyonga',
#  'portobelo',
#  'blieskastel',
#  'ovruch',
#  'ginda',
#  'disna',
#  'ballinrobe',
#  'buchanan',
#  'megion',
#  'ikom',
#  'hudiksvall',
#  'bolshoy tsaryn',
#  'granada',
#  'karakendzha',
#  'atar',
#  'goderich',
#  'westport',
#  'sedhiou',
#  'mesyagutovo',
#  'podgorica',
#  'benjamin aceval',
#  'rio grande',
#  'rorvik',
#  'puerto ayacucho',
#  'panjab',
#  'monrovia',
#  'borujerd',
#  'morondava',
#  'padang',
#  'aketi',
#  'corinto',
#  'la paz',
#  'nata',
#  'venice',
#  'plettenberg bay',
#  'abha',
#  'sedelnikovo',
#  'beryslav',
#  'karpenision',
#  'cua',
#  'tsaratanana',
#  'maragogi',
#  'moussoro',
#  'la ligua',
#  'varna',
#  'maldonado',
#  'mizdah',
#  'nueva guinea',
#  'paracatu',
#  'taloqan',
#  'novo oriente',
#  'rameswaram',
#  'natal',
#  'auxerre',
#  'sandviken',
#  'vangaindrano',
#  'ugoofaaru',
#  'pulawy',
#  'crotone',
#  'surt',
#  'axim',
#  'opuwo',
#  'kaspi',
#  'corinth',
#  'kolosovka',
#  'saint-francois',
#  'batticaloa',
#  'veshenskaya',
#  'tarko-sale',
#  'pirajui',
#  'calama',
#  'pankovka',
#  'kamenka',
#  'anantapur',
#  'anloga',
#  'syracuse',
#  'villamontes',
#  'kralendijk',
#  'coihueco',
#  'sawakin',
#  'kathor',
#  'filingue',
#  'savonlinna',
#  'pisz',
#  'le port',
#  'suratgarh',
#  'marcona',
#  'mitzic',
#  'maniitsoq',
#  'necochea',
#  'buncrana',
#  'aripuana',
#  'lydenburg',
#  'archena',
#  'odweyne',
#  'idah',
#  'cristalina',
#  'buraydah',
#  'mogadishu',
#  'karwar',
#  'sarkand',
#  'los llanos de aridane',
#  'ode',
#  'andarab',
#  'werda',
#  'clearwater',
#  'kipini',
#  'lukulu',
#  'belmonte',
#  'dunda',
#  'soure',
#  'artyom',
#  'sioux lookout',
#  'nalut',
#  'gravdal',
#  'sechura',
#  'neuquen',
#  'lukow',
#  'antalaha',
#  'cururupu',
#  'dehloran',
#  'portel',
#  'malwan',
#  'atlantic city',
#  'belize',
#  'geraldton',
#  'viedma',
#  'glenluce',
#  'sabya',
#  'inhambane',
#  'ferrol',
#  'nouakchott',
#  'jiwani',
#  'san carlos de bariloche',
#  'alvorada',
#  'douentza',
#  'burla',
#  'chancay',
#  'turinsk',
#  'calvinia',
#  'kidal',
#  'kasongo-lunda',
#  'nouadhibou',
#  'tatawin',
#  'ozgon',
#  'bluefield',
#  'gvarv',
#  'mollendo',
#  'marzuq',
#  'masasi',
#  'aljezur',
#  'freeport',
#  'usinsk',
#  'belogorsk',
#  'dibaya',
#  'tiruchchendur',
#  'lagos',
#  'bud',
#  'novobirilyussy',
#  'sao joaquim',
#  'saint-louis',
#  'goldap',
#  'benguela',
#  'staryy nadym',
#  'vestmanna',
#  'iquique',
#  'salym',
#  'puerto maldonado',
#  'vila franca do campo',
#  'vestmannaeyjar',
#  'ouallam',
#  'podporozhye',
#  'sept-iles',
#  'andevoranto',
#  'rantoul',
#  'general roca',
#  'herat',
#  'peterhead',
#  'codajas',
#  'pedernales',
#  'kyshtovka',
#  'rosa zarate',
#  'zhanaozen',
#  'baherden',
#  'csomor',
#  'koungheul',
#  'kibala',
#  'diamantino',
#  'chicama',
#  'aksu',
#  'koygorodok',
#  'burica',
#  'konde',
#  'nanuque',
#  'acari',
#  'grand-santi',
#  'pobe',
#  'caraubas',
#  'itacarambi',
#  'puri',
#  'chipinge',
#  'valreas',
#  'ajdabiya',
#  'beyneu',
#  'kovur',
#  'bereda',
#  'bolshaya martynovka',
#  'tunceli',
#  'carauari',
#  'mangochi',
#  'sunbury',
#  'semnan',
#  'mitsamiouli',
#  'mtwango',
#  'corralillo',
#  'srivardhan',
#  'saint-marc',
#  'morristown',
#  'iralaya',
#  'dabakala',
#  'humberto de campos',
#  'karaidel',
#  'tasgaon',
#  'storsteinnes',
#  'matagami',
#  'prieska',
#  'cah ab',
#  'azul',
#  'chapleau',
#  'duku',
#  'mabaruma',
#  'iisalmi',
#  'tabuk',
#  'mehran',
#  'chimore',
#  'sayyan',
#  'urucara',
#  'duminichi',
#  'veraval',
#  'barra do garcas',
#  'dawlatabad',
#  'mana',
#  'saint-georges',
#  'atyrau',
#  'tshikapa',
#  'goure',
#  'wukari',
#  'elizabeth city',
#  'krasnovka',
#  'birjand',
#  'wattegama',
#  'tazovskiy',
#  'jumla',
#  'beauceville',
#  'puerto del rosario',
#  'likasi',
#  'villarrica']

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime
url="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        description = city_weather['weather'][0]['description']
        
        # Convert the date to ISO
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information to the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":description })


# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | marsabit
# Processing Record 2 of Set 1 | matsanga
# City not found. Skipping...
# Processing Record 3 of Set 1 | cape town
# Processing Record 4 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 5 of Set 1 | namibe
# Processing Record 6 of Set 1 | bambous virieux
# Processing Record 7 of Set 1 | talnakh
# Processing Record 8 of Set 1 | saint-augustin
# Processing Record 9 of Set 1 | bredasdorp
# Processing Record 10 of Set 1 | lesnoy
# Processing Record 11 of Set 1 | longyearbyen
# Processing Record 12 of Set 1 | sambava
# Processing Record 13 of Set 1 | mahebourg
# Processing Record 14 of Set 1 | inta
# Processing Record 15 of Set 1 | jamestown
# Processing Record 16 of Set 1 | walvis bay
# Processing Record 17 of Set 1 | hermanus
# Processing Record 18 of Set 1 | caravelas
# Processing Record 19 of Set 1 | bandarbeyla
# Processing Record 20 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 21 of Set 1 | east london
# Processing Record 22 of Set 1 | mecca
# Processing Record 23 of Set 1 | souillac
# Processing Record 24 of Set 1 | moose factory
# Processing Record 25 of Set 1 | port alfred
# Processing Record 26 of Set 1 | umm kaddadah
# Processing Record 27 of Set 1 | klaksvik
# Processing Record 28 of Set 1 | cobija
# Processing Record 29 of Set 1 | savinka
# Processing Record 30 of Set 1 | kolyvan
# Processing Record 31 of Set 1 | dikson
# Processing Record 32 of Set 1 | lodwar
# Processing Record 33 of Set 1 | burgersdorp
# Processing Record 34 of Set 1 | lasa
# Processing Record 35 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 36 of Set 1 | lagoa
# Processing Record 37 of Set 1 | grand gaube
# Processing Record 38 of Set 1 | bharatpur
# Processing Record 39 of Set 1 | taoudenni
# Processing Record 40 of Set 1 | ushuaia
# Processing Record 41 of Set 1 | lebu
# Processing Record 42 of Set 1 | sao filipe
# Processing Record 43 of Set 1 | olafsvik
# Processing Record 44 of Set 1 | qaanaaq
# Processing Record 45 of Set 1 | matara
# Processing Record 46 of Set 1 | warqla
# City not found. Skipping...
# Processing Record 47 of Set 1 | punta arenas
# Processing Record 48 of Set 1 | leh
# Processing Record 49 of Set 1 | vyartsilya
# Processing Record 50 of Set 1 | sorland
# Processing Record 1 of Set 2 | vicuna
# Processing Record 2 of Set 2 | coruripe
# Processing Record 3 of Set 2 | senno
# Processing Record 4 of Set 2 | dokshukino
# City not found. Skipping...
# Processing Record 5 of Set 2 | kudahuvadhoo
# Processing Record 6 of Set 2 | yar-sale
# Processing Record 7 of Set 2 | upernavik
# Processing Record 8 of Set 2 | mamlyutka
# Processing Record 9 of Set 2 | rio cuarto
# Processing Record 10 of Set 2 | paramonga
# Processing Record 11 of Set 2 | doaba
# Processing Record 12 of Set 2 | busselton
# Processing Record 13 of Set 2 | touros
# Processing Record 14 of Set 2 | yarada
# Processing Record 15 of Set 2 | ambodifototra
# City not found. Skipping...
# Processing Record 16 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 2 | ribeira grande
# Processing Record 18 of Set 2 | santarem
# Processing Record 19 of Set 2 | muli
# Processing Record 20 of Set 2 | volchikha
# Processing Record 21 of Set 2 | cidreira
# Processing Record 22 of Set 2 | chinhoyi
# Processing Record 23 of Set 2 | aswan
# Processing Record 24 of Set 2 | kavaratti
# Processing Record 25 of Set 2 | margate
# Processing Record 26 of Set 2 | codrington
# Processing Record 27 of Set 2 | amparafaravola
# Processing Record 28 of Set 2 | tiznit
# Processing Record 29 of Set 2 | ipojuca
# Processing Record 30 of Set 2 | tilsonburg
# City not found. Skipping...
# Processing Record 31 of Set 2 | marsa matruh
# Processing Record 32 of Set 2 | hofn
# Processing Record 33 of Set 2 | saint-pierre
# Processing Record 34 of Set 2 | bibbiena
# Processing Record 35 of Set 2 | cuenca
# Processing Record 36 of Set 2 | tasiilaq
# Processing Record 37 of Set 2 | strezhevoy
# Processing Record 38 of Set 2 | hun
# Processing Record 39 of Set 2 | kruisfontein
# Processing Record 40 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 41 of Set 2 | georgetown
# Processing Record 42 of Set 2 | pauini
# Processing Record 43 of Set 2 | cerro grande
# Processing Record 44 of Set 2 | aksarka
# Processing Record 45 of Set 2 | muzaffarabad
# Processing Record 46 of Set 2 | saint-denis
# Processing Record 47 of Set 2 | ponta do sol
# Processing Record 48 of Set 2 | arraial do cabo
# Processing Record 49 of Set 2 | salalah
# Processing Record 50 of Set 2 | revda
# Processing Record 1 of Set 3 | dingle
# Processing Record 2 of Set 3 | richards bay
# Processing Record 3 of Set 3 | wajid
# Processing Record 4 of Set 3 | iqaluit
# Processing Record 5 of Set 3 | copiapo
# Processing Record 6 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 7 of Set 3 | macaiba
# Processing Record 8 of Set 3 | nara
# Processing Record 9 of Set 3 | saint-philippe
# Processing Record 10 of Set 3 | huarmey
# Processing Record 11 of Set 3 | camopi
# Processing Record 12 of Set 3 | ourossogui
# Processing Record 13 of Set 3 | oktyabrskoye
# Processing Record 14 of Set 3 | barranca
# Processing Record 15 of Set 3 | vila velha
# Processing Record 16 of Set 3 | hithadhoo
# Processing Record 17 of Set 3 | ayagoz
# Processing Record 18 of Set 3 | grenaa
# Processing Record 19 of Set 3 | ndioum
# Processing Record 20 of Set 3 | soyo
# Processing Record 21 of Set 3 | torbay
# Processing Record 22 of Set 3 | dakar
# Processing Record 23 of Set 3 | skalistyy
# City not found. Skipping...
# Processing Record 24 of Set 3 | victoria
# Processing Record 25 of Set 3 | bayshore gardens
# Processing Record 26 of Set 3 | kargasok
# Processing Record 27 of Set 3 | kulhudhuffushi
# Processing Record 28 of Set 3 | clyde river
# Processing Record 29 of Set 3 | bugarama
# Processing Record 30 of Set 3 | mehamn
# Processing Record 31 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 32 of Set 3 | sakakah
# Processing Record 33 of Set 3 | stod
# Processing Record 34 of Set 3 | port-cartier
# Processing Record 35 of Set 3 | encantado
# Processing Record 36 of Set 3 | quepos
# Processing Record 37 of Set 3 | lethem
# Processing Record 38 of Set 3 | kattivakkam
# Processing Record 39 of Set 3 | barcelos
# Processing Record 40 of Set 3 | narsaq
# Processing Record 41 of Set 3 | abu samrah
# Processing Record 42 of Set 3 | comodoro rivadavia
# Processing Record 43 of Set 3 | mar del plata
# Processing Record 44 of Set 3 | hualmay
# Processing Record 45 of Set 3 | iranshahr
# Processing Record 46 of Set 3 | babanusah
# City not found. Skipping...
# Processing Record 47 of Set 3 | arinos
# Processing Record 48 of Set 3 | januaria
# Processing Record 49 of Set 3 | constitucion
# Processing Record 50 of Set 3 | mayumba
# Processing Record 1 of Set 4 | brasilia de minas
# Processing Record 2 of Set 4 | rurrenabaque
# Processing Record 3 of Set 4 | sidi ali
# Processing Record 4 of Set 4 | coquimbo
# Processing Record 5 of Set 4 | manturovo
# Processing Record 6 of Set 4 | naron
# Processing Record 7 of Set 4 | husavik
# Processing Record 8 of Set 4 | port hawkesbury
# Processing Record 9 of Set 4 | luderitz
# Processing Record 10 of Set 4 | barawe
# City not found. Skipping...
# Processing Record 11 of Set 4 | rocha
# Processing Record 12 of Set 4 | girua
# Processing Record 13 of Set 4 | acarigua
# Processing Record 14 of Set 4 | ampanihy
# Processing Record 15 of Set 4 | santa cruz
# Processing Record 16 of Set 4 | coari
# Processing Record 17 of Set 4 | corn island
# Processing Record 18 of Set 4 | najran
# Processing Record 19 of Set 4 | saint george
# Processing Record 20 of Set 4 | bocas del toro
# Processing Record 21 of Set 4 | belyy yar
# Processing Record 22 of Set 4 | polunochnoye
# Processing Record 23 of Set 4 | malkara
# Processing Record 24 of Set 4 | rawson
# Processing Record 25 of Set 4 | jalu
# Processing Record 26 of Set 4 | ostersund
# Processing Record 27 of Set 4 | el cobre
# Processing Record 28 of Set 4 | beruwala
# Processing Record 29 of Set 4 | nanortalik
# Processing Record 30 of Set 4 | barabinsk
# Processing Record 31 of Set 4 | nove hrady
# Processing Record 32 of Set 4 | cheveresu mare
# Processing Record 33 of Set 4 | winneba
# Processing Record 34 of Set 4 | rome
# Processing Record 35 of Set 4 | roald
# Processing Record 36 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 37 of Set 4 | ostrovnoy
# Processing Record 38 of Set 4 | ancud
# Processing Record 39 of Set 4 | asasa
# Processing Record 40 of Set 4 | biltine
# Processing Record 41 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 42 of Set 4 | marsh harbour
# Processing Record 43 of Set 4 | jacareacanga
# Processing Record 44 of Set 4 | hamilton
# Processing Record 45 of Set 4 | ladwa
# Processing Record 46 of Set 4 | faya
# City not found. Skipping...
# Processing Record 47 of Set 4 | caucaia
# Processing Record 48 of Set 4 | camacha
# Processing Record 49 of Set 4 | zhovti vody
# Processing Record 50 of Set 4 | paamiut
# Processing Record 1 of Set 5 | hambantota
# Processing Record 2 of Set 5 | port blair
# Processing Record 3 of Set 5 | toamasina
# Processing Record 4 of Set 5 | bathsheba
# Processing Record 5 of Set 5 | kampene
# Processing Record 6 of Set 5 | kulachi
# Processing Record 7 of Set 5 | puerto baquerizo moreno
# Processing Record 8 of Set 5 | omboue
# Processing Record 9 of Set 5 | new glasgow
# Processing Record 10 of Set 5 | butembo
# Processing Record 11 of Set 5 | sistranda
# Processing Record 12 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 13 of Set 5 | muscat
# Processing Record 14 of Set 5 | harper
# Processing Record 15 of Set 5 | eatonton
# Processing Record 16 of Set 5 | tamandare
# Processing Record 17 of Set 5 | saldanha
# Processing Record 18 of Set 5 | oranjemund
# Processing Record 19 of Set 5 | utica
# Processing Record 20 of Set 5 | mocambique
# City not found. Skipping...
# Processing Record 21 of Set 5 | castro
# Processing Record 22 of Set 5 | chuy
# Processing Record 23 of Set 5 | galle
# Processing Record 24 of Set 5 | darnah
# Processing Record 25 of Set 5 | terenos
# Processing Record 26 of Set 5 | ambilobe
# Processing Record 27 of Set 5 | skjervoy
# Processing Record 28 of Set 5 | krasnoselkup
# Processing Record 29 of Set 5 | ongandjera
# Processing Record 30 of Set 5 | kazalinsk
# City not found. Skipping...
# Processing Record 31 of Set 5 | cabedelo
# Processing Record 32 of Set 5 | vardo
# Processing Record 33 of Set 5 | den helder
# Processing Record 34 of Set 5 | mercedes
# Processing Record 35 of Set 5 | stornoway
# Processing Record 36 of Set 5 | bujumbura
# Processing Record 37 of Set 5 | sobradinho
# Processing Record 38 of Set 5 | bardiyah
# Processing Record 39 of Set 5 | badarganj
# Processing Record 40 of Set 5 | altay
# Processing Record 41 of Set 5 | lohja
# Processing Record 42 of Set 5 | bauchi
# Processing Record 43 of Set 5 | guane
# Processing Record 44 of Set 5 | ilulissat
# Processing Record 45 of Set 5 | sinnamary
# Processing Record 46 of Set 5 | thunder bay
# Processing Record 47 of Set 5 | kuryk
# Processing Record 48 of Set 5 | olinda
# Processing Record 49 of Set 5 | mutare
# Processing Record 50 of Set 5 | pisco
# Processing Record 1 of Set 6 | coxim
# Processing Record 2 of Set 6 | bonavista
# Processing Record 3 of Set 6 | halifax
# Processing Record 4 of Set 6 | kalmunai
# Processing Record 5 of Set 6 | abaza
# Processing Record 6 of Set 6 | fomboni
# Processing Record 7 of Set 6 | rio gallegos
# Processing Record 8 of Set 6 | ponta pora
# Processing Record 9 of Set 6 | nador
# Processing Record 10 of Set 6 | port elizabeth
# Processing Record 11 of Set 6 | thinadhoo
# Processing Record 12 of Set 6 | santa isabel do rio negro
# Processing Record 13 of Set 6 | evinayong
# Processing Record 14 of Set 6 | sliema
# Processing Record 15 of Set 6 | areosa
# Processing Record 16 of Set 6 | maceio
# Processing Record 17 of Set 6 | acarau
# Processing Record 18 of Set 6 | iberia
# Processing Record 19 of Set 6 | almazar
# Processing Record 20 of Set 6 | tarauaca
# Processing Record 21 of Set 6 | makokou
# Processing Record 22 of Set 6 | longlac
# City not found. Skipping...
# Processing Record 23 of Set 6 | shieli
# Processing Record 24 of Set 6 | altamira
# Processing Record 25 of Set 6 | bilma
# Processing Record 26 of Set 6 | porto novo
# Processing Record 27 of Set 6 | esil
# Processing Record 28 of Set 6 | buta
# Processing Record 29 of Set 6 | formoso do araguaia
# City not found. Skipping...
# Processing Record 30 of Set 6 | beisfjord
# Processing Record 31 of Set 6 | shenkursk
# Processing Record 32 of Set 6 | brae
# Processing Record 33 of Set 6 | svilajnac
# Processing Record 34 of Set 6 | lokosovo
# Processing Record 35 of Set 6 | ponta delgada
# Processing Record 36 of Set 6 | young
# Processing Record 37 of Set 6 | sajanan
# Processing Record 38 of Set 6 | raudeberg
# Processing Record 39 of Set 6 | emba
# Processing Record 40 of Set 6 | tartagal
# Processing Record 41 of Set 6 | doha
# Processing Record 42 of Set 6 | barbar
# City not found. Skipping...
# Processing Record 43 of Set 6 | appleton
# Processing Record 44 of Set 6 | mrirt
# City not found. Skipping...
# Processing Record 45 of Set 6 | bosaso
# Processing Record 46 of Set 6 | lajoskomarom
# Processing Record 47 of Set 6 | sao felix do xingu
# Processing Record 48 of Set 6 | lincoln
# Processing Record 49 of Set 6 | khromtau
# Processing Record 50 of Set 6 | oriximina
# Processing Record 1 of Set 7 | oksbol
# Processing Record 2 of Set 7 | uch
# Processing Record 3 of Set 7 | wa
# City not found. Skipping...
# Processing Record 4 of Set 7 | kismayo
# Processing Record 5 of Set 7 | kaduqli
# Processing Record 6 of Set 7 | paita
# Processing Record 7 of Set 7 | kodino
# Processing Record 8 of Set 7 | patrocinio
# Processing Record 9 of Set 7 | sao joao da barra
# Processing Record 10 of Set 7 | tambul
# City not found. Skipping...
# Processing Record 11 of Set 7 | takob
# City not found. Skipping...
# Processing Record 12 of Set 7 | zanjan
# Processing Record 13 of Set 7 | ratnagiri
# Processing Record 14 of Set 7 | naryan-mar
# Processing Record 15 of Set 7 | kouango
# Processing Record 16 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 17 of Set 7 | praia da vitoria
# Processing Record 18 of Set 7 | damghan
# Processing Record 19 of Set 7 | belmont
# Processing Record 20 of Set 7 | caiaponia
# Processing Record 21 of Set 7 | vista hermosa
# Processing Record 22 of Set 7 | carutapera
# Processing Record 23 of Set 7 | lumeje
# Processing Record 24 of Set 7 | crateus
# Processing Record 25 of Set 7 | esik
# Processing Record 26 of Set 7 | do gonbadan
# Processing Record 27 of Set 7 | pitimbu
# Processing Record 28 of Set 7 | solovetskiy
# City not found. Skipping...
# Processing Record 29 of Set 7 | lyubeshiv
# City not found. Skipping...
# Processing Record 30 of Set 7 | akdepe
# Processing Record 31 of Set 7 | voyvozh
# Processing Record 32 of Set 7 | mount pleasant
# Processing Record 33 of Set 7 | havelock
# Processing Record 34 of Set 7 | warrington
# Processing Record 35 of Set 7 | mookane
# Processing Record 36 of Set 7 | quthing
# Processing Record 37 of Set 7 | menongue
# Processing Record 38 of Set 7 | havoysund
# Processing Record 39 of Set 7 | palma del rio
# Processing Record 40 of Set 7 | laguna
# Processing Record 41 of Set 7 | bonthe
# Processing Record 42 of Set 7 | montepuez
# Processing Record 43 of Set 7 | tacuarembo
# Processing Record 44 of Set 7 | cayenne
# Processing Record 45 of Set 7 | umm jarr
# City not found. Skipping...
# Processing Record 46 of Set 7 | emirdag
# Processing Record 47 of Set 7 | ribas do rio pardo
# Processing Record 48 of Set 7 | tuggurt
# City not found. Skipping...
# Processing Record 49 of Set 7 | jaciara
# Processing Record 50 of Set 7 | rey bouba
# Processing Record 1 of Set 8 | tocopilla
# Processing Record 2 of Set 8 | mamou
# Processing Record 3 of Set 8 | montana
# Processing Record 4 of Set 8 | rodrigues alves
# Processing Record 5 of Set 8 | dzhusaly
# City not found. Skipping...
# Processing Record 6 of Set 8 | juazeiro
# Processing Record 7 of Set 8 | takoradi
# Processing Record 8 of Set 8 | keetmanshoop
# Processing Record 9 of Set 8 | madras
# Processing Record 10 of Set 8 | antri
# Processing Record 11 of Set 8 | qasigiannguit
# Processing Record 12 of Set 8 | araouane
# Processing Record 13 of Set 8 | san luis
# Processing Record 14 of Set 8 | behbahan
# Processing Record 15 of Set 8 | larsnes
# Processing Record 16 of Set 8 | carnarvon
# Processing Record 17 of Set 8 | ilinskaya
# Processing Record 18 of Set 8 | luanda
# Processing Record 19 of Set 8 | dudinka
# Processing Record 20 of Set 8 | tena
# Processing Record 21 of Set 8 | bubaque
# Processing Record 22 of Set 8 | palma di montechiaro
# Processing Record 23 of Set 8 | wolow
# Processing Record 24 of Set 8 | north myrtle beach
# Processing Record 25 of Set 8 | camabatela
# Processing Record 26 of Set 8 | miranda
# Processing Record 27 of Set 8 | cockburn town
# Processing Record 28 of Set 8 | filadelfia
# Processing Record 29 of Set 8 | ust-kulom
# Processing Record 30 of Set 8 | staryy biser
# City not found. Skipping...
# Processing Record 31 of Set 8 | korla
# Processing Record 32 of Set 8 | nicoya
# Processing Record 33 of Set 8 | antofagasta
# Processing Record 34 of Set 8 | diffa
# Processing Record 35 of Set 8 | kastamonu
# Processing Record 36 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 37 of Set 8 | saint-joseph
# Processing Record 38 of Set 8 | gasa
# Processing Record 39 of Set 8 | agirish
# Processing Record 40 of Set 8 | marawi
# Processing Record 41 of Set 8 | pangnirtung
# Processing Record 42 of Set 8 | arlit
# Processing Record 43 of Set 8 | sao borja
# Processing Record 44 of Set 8 | joensuu
# Processing Record 45 of Set 8 | chapais
# Processing Record 46 of Set 8 | george town
# Processing Record 47 of Set 8 | pampierstad
# Processing Record 48 of Set 8 | thompson
# Processing Record 49 of Set 8 | visby
# Processing Record 50 of Set 8 | falun
# Processing Record 1 of Set 9 | ilhabela
# Processing Record 2 of Set 9 | votorantim
# Processing Record 3 of Set 9 | alberton
# Processing Record 4 of Set 9 | turukhansk
# Processing Record 5 of Set 9 | hobyo
# Processing Record 6 of Set 9 | bukama
# Processing Record 7 of Set 9 | ituango
# Processing Record 8 of Set 9 | oxapampa
# Processing Record 9 of Set 9 | male
# Processing Record 10 of Set 9 | ouesso
# Processing Record 11 of Set 9 | itarema
# Processing Record 12 of Set 9 | leshukonskoye
# Processing Record 13 of Set 9 | gazojak
# Processing Record 14 of Set 9 | pitkyaranta
# Processing Record 15 of Set 9 | san juan bautista
# Processing Record 16 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 17 of Set 9 | itacoatiara
# Processing Record 18 of Set 9 | sur
# Processing Record 19 of Set 9 | surab
# Processing Record 20 of Set 9 | viseu
# Processing Record 21 of Set 9 | muskegon
# Processing Record 22 of Set 9 | coihaique
# Processing Record 23 of Set 9 | zharkent
# Processing Record 24 of Set 9 | havre-saint-pierre
# Processing Record 25 of Set 9 | oktyabrskiy
# Processing Record 26 of Set 9 | oksfjord
# Processing Record 27 of Set 9 | mali
# Processing Record 28 of Set 9 | monze
# Processing Record 29 of Set 9 | salinopolis
# Processing Record 30 of Set 9 | rostov-na-donu
# Processing Record 31 of Set 9 | silvan
# Processing Record 32 of Set 9 | adrar
# Processing Record 33 of Set 9 | henties bay
# Processing Record 34 of Set 9 | porechye-rybnoye
# Processing Record 35 of Set 9 | san jose de guanipa
# Processing Record 36 of Set 9 | manati
# Processing Record 37 of Set 9 | lai
# Processing Record 38 of Set 9 | gat
# Processing Record 39 of Set 9 | semey
# Processing Record 40 of Set 9 | manassas
# Processing Record 41 of Set 9 | berlevag
# Processing Record 42 of Set 9 | otavi
# Processing Record 43 of Set 9 | mustafakemalpasa
# Processing Record 44 of Set 9 | borba
# Processing Record 45 of Set 9 | inongo
# Processing Record 46 of Set 9 | koslan
# Processing Record 47 of Set 9 | shahrud
# Processing Record 48 of Set 9 | grindavik
# Processing Record 49 of Set 9 | jutai
# Processing Record 50 of Set 9 | qaqortoq
# Processing Record 1 of Set 10 | bell ville
# Processing Record 2 of Set 10 | gijon
# Processing Record 3 of Set 10 | mocajuba
# Processing Record 4 of Set 10 | synya
# Processing Record 5 of Set 10 | san ignacio
# Processing Record 6 of Set 10 | anyksciai
# Processing Record 7 of Set 10 | saurimo
# Processing Record 8 of Set 10 | san cristobal
# Processing Record 9 of Set 10 | kargil
# Processing Record 10 of Set 10 | impfondo
# Processing Record 11 of Set 10 | salekhard
# Processing Record 12 of Set 10 | krasnoyarka
# Processing Record 13 of Set 10 | traverse city
# Processing Record 14 of Set 10 | imbituba
# Processing Record 15 of Set 10 | keti bandar
# Processing Record 16 of Set 10 | kupino
# Processing Record 17 of Set 10 | san vicente
# Processing Record 18 of Set 10 | poli
# Processing Record 19 of Set 10 | wanlaweyn
# Processing Record 20 of Set 10 | rundu
# Processing Record 21 of Set 10 | avanigadda
# Processing Record 22 of Set 10 | carbonia
# Processing Record 23 of Set 10 | san juan
# Processing Record 24 of Set 10 | andenes
# Processing Record 25 of Set 10 | basoko
# Processing Record 26 of Set 10 | bandar-e lengeh
# Processing Record 27 of Set 10 | dubna
# Processing Record 28 of Set 10 | gubkinskiy
# Processing Record 29 of Set 10 | adeje
# Processing Record 30 of Set 10 | cangucu
# Processing Record 31 of Set 10 | ituni
# City not found. Skipping...
# Processing Record 32 of Set 10 | inyonga
# Processing Record 33 of Set 10 | portobelo
# Processing Record 34 of Set 10 | blieskastel
# Processing Record 35 of Set 10 | ovruch
# Processing Record 36 of Set 10 | ginda
# Processing Record 37 of Set 10 | disna
# Processing Record 38 of Set 10 | ballinrobe
# Processing Record 39 of Set 10 | buchanan
# Processing Record 40 of Set 10 | megion
# Processing Record 41 of Set 10 | ikom
# Processing Record 42 of Set 10 | hudiksvall
# Processing Record 43 of Set 10 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 44 of Set 10 | granada
# Processing Record 45 of Set 10 | karakendzha
# City not found. Skipping...
# Processing Record 46 of Set 10 | atar
# Processing Record 47 of Set 10 | goderich
# Processing Record 48 of Set 10 | westport
# Processing Record 49 of Set 10 | sedhiou
# Processing Record 50 of Set 10 | mesyagutovo
# Processing Record 1 of Set 11 | podgorica
# Processing Record 2 of Set 11 | benjamin aceval
# Processing Record 3 of Set 11 | rio grande
# Processing Record 4 of Set 11 | rorvik
# Processing Record 5 of Set 11 | puerto ayacucho
# Processing Record 6 of Set 11 | panjab
# Processing Record 7 of Set 11 | monrovia
# Processing Record 8 of Set 11 | borujerd
# Processing Record 9 of Set 11 | morondava
# Processing Record 10 of Set 11 | padang
# Processing Record 11 of Set 11 | aketi
# Processing Record 12 of Set 11 | corinto
# Processing Record 13 of Set 11 | la paz
# Processing Record 14 of Set 11 | nata
# Processing Record 15 of Set 11 | venice
# Processing Record 16 of Set 11 | plettenberg bay
# Processing Record 17 of Set 11 | abha
# Processing Record 18 of Set 11 | sedelnikovo
# City not found. Skipping...
# Processing Record 19 of Set 11 | beryslav
# Processing Record 20 of Set 11 | karpenision
# City not found. Skipping...
# Processing Record 21 of Set 11 | cua
# Processing Record 22 of Set 11 | tsaratanana
# Processing Record 23 of Set 11 | maragogi
# Processing Record 24 of Set 11 | moussoro
# Processing Record 25 of Set 11 | la ligua
# Processing Record 26 of Set 11 | varna
# Processing Record 27 of Set 11 | maldonado
# Processing Record 28 of Set 11 | mizdah
# Processing Record 29 of Set 11 | nueva guinea
# Processing Record 30 of Set 11 | paracatu
# Processing Record 31 of Set 11 | taloqan
# Processing Record 32 of Set 11 | novo oriente
# Processing Record 33 of Set 11 | rameswaram
# Processing Record 34 of Set 11 | natal
# Processing Record 35 of Set 11 | auxerre
# Processing Record 36 of Set 11 | sandviken
# Processing Record 37 of Set 11 | vangaindrano
# Processing Record 38 of Set 11 | ugoofaaru
# Processing Record 39 of Set 11 | pulawy
# Processing Record 40 of Set 11 | crotone
# Processing Record 41 of Set 11 | surt
# Processing Record 42 of Set 11 | axim
# Processing Record 43 of Set 11 | opuwo
# Processing Record 44 of Set 11 | kaspi
# Processing Record 45 of Set 11 | corinth
# Processing Record 46 of Set 11 | kolosovka
# Processing Record 47 of Set 11 | saint-francois
# Processing Record 48 of Set 11 | batticaloa
# Processing Record 49 of Set 11 | veshenskaya
# Processing Record 50 of Set 11 | tarko-sale
# Processing Record 1 of Set 12 | pirajui
# Processing Record 2 of Set 12 | calama
# Processing Record 3 of Set 12 | pankovka
# Processing Record 4 of Set 12 | kamenka
# Processing Record 5 of Set 12 | anantapur
# Processing Record 6 of Set 12 | anloga
# Processing Record 7 of Set 12 | syracuse
# Processing Record 8 of Set 12 | villamontes
# Processing Record 9 of Set 12 | kralendijk
# Processing Record 10 of Set 12 | coihueco
# Processing Record 11 of Set 12 | sawakin
# Processing Record 12 of Set 12 | kathor
# Processing Record 13 of Set 12 | filingue
# Processing Record 14 of Set 12 | savonlinna
# Processing Record 15 of Set 12 | pisz
# Processing Record 16 of Set 12 | le port
# Processing Record 17 of Set 12 | suratgarh
# Processing Record 18 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 19 of Set 12 | mitzic
# Processing Record 20 of Set 12 | maniitsoq
# Processing Record 21 of Set 12 | necochea
# Processing Record 22 of Set 12 | buncrana
# Processing Record 23 of Set 12 | aripuana
# Processing Record 24 of Set 12 | lydenburg
# Processing Record 25 of Set 12 | archena
# Processing Record 26 of Set 12 | odweyne
# Processing Record 27 of Set 12 | idah
# Processing Record 28 of Set 12 | cristalina
# Processing Record 29 of Set 12 | buraydah
# Processing Record 30 of Set 12 | mogadishu
# Processing Record 31 of Set 12 | karwar
# Processing Record 32 of Set 12 | sarkand
# Processing Record 33 of Set 12 | los llanos de aridane
# Processing Record 34 of Set 12 | ode
# Processing Record 35 of Set 12 | andarab
# City not found. Skipping...
# Processing Record 36 of Set 12 | werda
# Processing Record 37 of Set 12 | clearwater
# Processing Record 38 of Set 12 | kipini
# Processing Record 39 of Set 12 | lukulu
# Processing Record 40 of Set 12 | belmonte
# Processing Record 41 of Set 12 | dunda
# Processing Record 42 of Set 12 | soure
# Processing Record 43 of Set 12 | artyom
# Processing Record 44 of Set 12 | sioux lookout
# Processing Record 45 of Set 12 | nalut
# Processing Record 46 of Set 12 | gravdal
# Processing Record 47 of Set 12 | sechura
# Processing Record 48 of Set 12 | neuquen
# Processing Record 49 of Set 12 | lukow
# Processing Record 50 of Set 12 | antalaha
# Processing Record 1 of Set 13 | cururupu
# Processing Record 2 of Set 13 | dehloran
# Processing Record 3 of Set 13 | portel
# Processing Record 4 of Set 13 | malwan
# City not found. Skipping...
# Processing Record 5 of Set 13 | atlantic city
# Processing Record 6 of Set 13 | belize
# Processing Record 7 of Set 13 | geraldton
# Processing Record 8 of Set 13 | viedma
# Processing Record 9 of Set 13 | glenluce
# Processing Record 10 of Set 13 | sabya
# Processing Record 11 of Set 13 | inhambane
# Processing Record 12 of Set 13 | ferrol
# Processing Record 13 of Set 13 | nouakchott
# Processing Record 14 of Set 13 | jiwani
# Processing Record 15 of Set 13 | san carlos de bariloche
# Processing Record 16 of Set 13 | alvorada
# Processing Record 17 of Set 13 | douentza
# Processing Record 18 of Set 13 | burla
# Processing Record 19 of Set 13 | chancay
# Processing Record 20 of Set 13 | turinsk
# Processing Record 21 of Set 13 | calvinia
# Processing Record 22 of Set 13 | kidal
# Processing Record 23 of Set 13 | kasongo-lunda
# Processing Record 24 of Set 13 | nouadhibou
# Processing Record 25 of Set 13 | tatawin
# Processing Record 26 of Set 13 | ozgon
# City not found. Skipping...
# Processing Record 27 of Set 13 | bluefield
# Processing Record 28 of Set 13 | gvarv
# Processing Record 29 of Set 13 | mollendo
# Processing Record 30 of Set 13 | marzuq
# Processing Record 31 of Set 13 | masasi
# Processing Record 32 of Set 13 | aljezur
# Processing Record 33 of Set 13 | freeport
# Processing Record 34 of Set 13 | usinsk
# Processing Record 35 of Set 13 | belogorsk
# Processing Record 36 of Set 13 | dibaya
# City not found. Skipping...
# Processing Record 37 of Set 13 | tiruchchendur
# Processing Record 38 of Set 13 | lagos
# Processing Record 39 of Set 13 | bud
# Processing Record 40 of Set 13 | novobirilyussy
# Processing Record 41 of Set 13 | sao joaquim
# Processing Record 42 of Set 13 | saint-louis
# Processing Record 43 of Set 13 | goldap
# Processing Record 44 of Set 13 | benguela
# Processing Record 45 of Set 13 | staryy nadym
# Processing Record 46 of Set 13 | vestmanna
# Processing Record 47 of Set 13 | iquique
# Processing Record 48 of Set 13 | salym
# Processing Record 49 of Set 13 | puerto maldonado
# Processing Record 50 of Set 13 | vila franca do campo
# Processing Record 1 of Set 14 | vestmannaeyjar
# Processing Record 2 of Set 14 | ouallam
# Processing Record 3 of Set 14 | podporozhye
# Processing Record 4 of Set 14 | sept-iles
# Processing Record 5 of Set 14 | andevoranto
# City not found. Skipping...
# Processing Record 6 of Set 14 | rantoul
# Processing Record 7 of Set 14 | general roca
# Processing Record 8 of Set 14 | herat
# Processing Record 9 of Set 14 | peterhead
# Processing Record 10 of Set 14 | codajas
# Processing Record 11 of Set 14 | pedernales
# Processing Record 12 of Set 14 | kyshtovka
# Processing Record 13 of Set 14 | rosa zarate
# Processing Record 14 of Set 14 | zhanaozen
# Processing Record 15 of Set 14 | baherden
# Processing Record 16 of Set 14 | csomor
# Processing Record 17 of Set 14 | koungheul
# Processing Record 18 of Set 14 | kibala
# Processing Record 19 of Set 14 | diamantino
# Processing Record 20 of Set 14 | chicama
# Processing Record 21 of Set 14 | aksu
# Processing Record 22 of Set 14 | koygorodok
# Processing Record 23 of Set 14 | burica
# City not found. Skipping...
# Processing Record 24 of Set 14 | konde
# Processing Record 25 of Set 14 | nanuque
# Processing Record 26 of Set 14 | acari
# Processing Record 27 of Set 14 | grand-santi
# Processing Record 28 of Set 14 | pobe
# Processing Record 29 of Set 14 | caraubas
# Processing Record 30 of Set 14 | itacarambi
# Processing Record 31 of Set 14 | puri
# Processing Record 32 of Set 14 | chipinge
# Processing Record 33 of Set 14 | valreas
# Processing Record 34 of Set 14 | ajdabiya
# Processing Record 35 of Set 14 | beyneu
# Processing Record 36 of Set 14 | kovur
# Processing Record 37 of Set 14 | bereda
# Processing Record 38 of Set 14 | bolshaya martynovka
# Processing Record 39 of Set 14 | tunceli
# Processing Record 40 of Set 14 | carauari
# Processing Record 41 of Set 14 | mangochi
# Processing Record 42 of Set 14 | sunbury
# Processing Record 43 of Set 14 | semnan
# Processing Record 44 of Set 14 | mitsamiouli
# Processing Record 45 of Set 14 | mtwango
# Processing Record 46 of Set 14 | corralillo
# Processing Record 47 of Set 14 | srivardhan
# Processing Record 48 of Set 14 | saint-marc
# Processing Record 49 of Set 14 | morristown
# Processing Record 50 of Set 14 | iralaya
# Processing Record 1 of Set 15 | dabakala
# Processing Record 2 of Set 15 | humberto de campos
# Processing Record 3 of Set 15 | karaidel
# Processing Record 4 of Set 15 | tasgaon
# Processing Record 5 of Set 15 | storsteinnes
# Processing Record 6 of Set 15 | matagami
# Processing Record 7 of Set 15 | prieska
# Processing Record 8 of Set 15 | cah ab
# City not found. Skipping...
# Processing Record 9 of Set 15 | azul
# Processing Record 10 of Set 15 | chapleau
# Processing Record 11 of Set 15 | duku
# Processing Record 12 of Set 15 | mabaruma
# Processing Record 13 of Set 15 | iisalmi
# Processing Record 14 of Set 15 | tabuk
# Processing Record 15 of Set 15 | mehran
# Processing Record 16 of Set 15 | chimore
# Processing Record 17 of Set 15 | sayyan
# Processing Record 18 of Set 15 | urucara
# Processing Record 19 of Set 15 | duminichi
# Processing Record 20 of Set 15 | veraval
# Processing Record 21 of Set 15 | barra do garcas
# Processing Record 22 of Set 15 | dawlatabad
# Processing Record 23 of Set 15 | mana
# Processing Record 24 of Set 15 | saint-georges
# Processing Record 25 of Set 15 | atyrau
# Processing Record 26 of Set 15 | tshikapa
# Processing Record 27 of Set 15 | goure
# Processing Record 28 of Set 15 | wukari
# Processing Record 29 of Set 15 | elizabeth city
# Processing Record 30 of Set 15 | krasnovka
# Processing Record 31 of Set 15 | birjand
# Processing Record 32 of Set 15 | wattegama
# Processing Record 33 of Set 15 | tazovskiy
# Processing Record 34 of Set 15 | jumla
# Processing Record 35 of Set 15 | beauceville
# Processing Record 36 of Set 15 | puerto del rosario
# Processing Record 37 of Set 15 | likasi
# Processing Record 38 of Set 15 | villarrica
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 688

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0         Marsabit      KE   2.3284  37.9899     69.75        52          57
# 1        Cape Town      ZA -33.9258  18.4232     57.11        81           0
# 2           Namibe      AO -15.1961  12.1522     68.59        60           1
# 3  Bambous Virieux      MU -20.3428  57.7575     74.21        64          40
# 4          Talnakh      RU  69.4865  88.3972     61.21        34           6
# 5   Saint-Augustin      CA  51.2260 -58.6502     53.83        67         100
# 6       Bredasdorp      ZA -34.5322  20.0403     54.73        75           0
# 7           Lesnoy      RU  57.6198  63.0784     61.30        47          59
# 8     Longyearbyen      SJ  78.2186  15.6401     42.64        87          75
# 9          Sambava      MG -14.2667  50.1667     73.78        74          80
#
#    Wind Speed           Current Description
# 0       15.64                 broken clouds
# 1        4.61                     clear sky
# 2        6.38                     clear sky
# 3       12.66              scattered clouds
# 4       12.50                     clear sky
# 5       14.79               overcast clouds
# 6        0.38                     clear sky
# 7       10.85                 broken clouds
# 8        6.91  light intensity drizzle rain
# 9       15.12                    light rain

# %%
# Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder
# Create the output file (CSV).
output_data_file = "/Users/fanfan/Desktop/Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
